# %% [markdown]
# # 1 - Main Objectives
#
# The dataset we’ll provide you contains significantly messy data. Your job is to apply the different cleaning and manipulation techniques to generate a cleaner CSV version of this data.
#
# ## 1.1 - Make yourself focused
#
# Answer a ‘business’ question! Look for something you want to answer about shark attacks and try to answer that using data.This will focus your cleaning and data manipulation through the process.
#
# # 2 -The Dataset
#
# - Go to kaggle.com and create an account
# - Go to the search bar and look for ‘Global Shark Attacks’
# - Download the dataset
# - For more info: https:// www.sharkattackfile.net/
#
# # 3 - Hints
#
# - Use their website to understand the problem. Understanding the problem is a crucial step to developing good quality data solutions.
# - Be focused. The dataset is really messy. Every clean you make should have the goal to contribute to your answer.
#
# # 4 - Deliverables
#
# - A README.md file on GitHub describing your objectives and results.
# - The link to the Jupyter notebook (or the GitHub project)
#
# # 5 - MORE Objectives
#
# - One of the objectives of the current project is to show you the need of some techniques we will see in the future in the course. Of course, you don’t need to use them for now.
# - In the process of answering your question, we believe you’ll feel the need of some tools like:
# - Visualization techniques
# - Statistics
# - More data sources

# %% [markdown]
# # Project Start
#
# ## Importing requeired libraries

# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Loading dataframe

# %%
path = r'C:\Users\Daniel Jordan\OneDrive\Ironhack\ProJeto_Shark\Data\attacks.csv'
df_shark = pd.read_csv(path, encoding='ANSI')

# %% [markdown]
# ## Cleaning Null and Duplicated rows

# %%
df_shark.dropna(axis = 0, how = 'all', inplace = True)
df_shark.drop(columns=['Unnamed: 22', 'Unnamed: 23','Time', 'pdf', 'href formula', 'Name', 'Age', 'href', 'Species ', 'Investigator or Source' ], inplace=True)
df_shark.drop_duplicates(inplace=True)

# %% [markdown]
# ## Understending Dataframe

# %%
(df_shark['Case Number.1'] == df_shark['Case Number.2']).sum()
# Out:
# 6282

# %%
mask = df_shark['reported'].
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Daniel Jordan\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\Daniel Jordan\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\Daniel Jordan\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# ## Cheking if all data frame is complete

# %%
df_shark.dropna(inplace=True)
df_shark.isna().sum()
# Out:
# Case Number       0
# Date              0
# Year              0
# Type              0
# Country           0
# Area              0
# Location          0
# Activity          0
# Sex               0
# Injury            0
# Fatal (Y/N)       0
# Case Number.1     0
# Case Number.2     0
# original order    0
# dtype: int64

# %%
df_shark['Country'].unique()
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'SOUTH AFRICA',
#        'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'ECUADOR',
#        'MALAYSIA', 'CUBA', 'MAURITIUS', 'NEW ZEALAND', 'SPAIN', 'JAPAN',
#        'EGYPT', 'ST HELENA, British overseas territory',
#        'FRENCH POLYNESIA', 'UNITED KINGDOM', 'UNITED ARAB EMIRATES',
#        'REUNION', 'PHILIPPINES', 'INDONESIA', 'NEW CALEDONIA',
#        'DOMINICAN REPUBLIC', 'MOZAMBIQUE', 'FRANCE', 'ISRAEL', 'JAMAICA',
#        'NIGERIA', 'TONGA', 'SCOTLAND', 'ITALY', 'CHILE', 'TAIWAN',
#        'PAPUA NEW GUINEA', 'KENYA', 'RUSSIA', 'SEYCHELLES', 'COLUMBIA',
#        'TURKS & CAICOS', 'FIJI', 'SOUTH KOREA', 'VIETNAM', 'MADAGASCAR',
#        'UNITED ARAB EMIRATES (UAE)', 'PANAMA', 'SOLOMON ISLANDS', 'GUAM',
#        'CROATIA', 'NORWAY', 'Sierra Leone', 'ST. MAARTIN', 'GRAND CAYMAN',
#        'CHINA', 'VANUATU', 'MEXICO ', ' TONGA', 'URUGUAY', 'VENEZUELA',
# ...

# %%
df_shark['Activity'].unique()
# Out:
# array(['Paddling', 'Standing', 'Surfing', ...,
#        'Swimming around anchored ship',
#        'Crew swimming alongside their anchored ship',
#        '4 men were bathing'], dtype=object)

# %%
df_world = pd.read_csv(r'C:\Users\Daniel Jordan\OneDrive\Ironhack\ProJeto_Shark\Data\world.csv')
df_world['name']
# Out:
# 0                                            Afghanistan
# 1                                          Åland Islands
# 2                                                Albania
# 3                                                Algeria
# 4                                         American Samoa
# 5                                                Andorra
# 6                                                 Angola
# 7                                               Anguilla
# 8                                             Antarctica
# 9                                    Antigua and Barbuda
# 10                                             Argentina
# 11                                               Armenia
# 12                                                 Aruba
# 13                                             Australia
# 14                                               Austria
# 15                                            Azerbaijan
# ...

# %%
df_moon = pd.read_csv(r'C:\Users\Daniel Jordan\OneDrive\Ironhack\ProJeto_Shark\Data\full_moon.csv')
df_moon
# Out:
#             Day                Date                  Time
# 0        Monday     15 January 1900           08:07:30 pm
# 1     Wednesday    14 February 1900           02:50:12 pm
# 2        Friday       16 March 1900           09:11:48 am
# 3        Sunday       15 April 1900           02:02:06 am
# 4        Monday         14 May 1900           04:36:36 pm
# 5     Wednesday        13 June 1900           04:38:36 am
# 6      Thursday        12 July 1900           02:21:54 pm
# 7        Friday      10 August 1900           10:29:54 pm
# 8        Sunday    9 September 1900           06:06:06 am
# 9        Monday      8 October 1900           02:18:06 pm
# 10      Tuesday     6 November 1900           11:59:36 pm
# 11     Thursday     6 December 1900           11:38:06 am
# 12     Saturday      5 January 1901           01:13:24 am
# 13       Sunday     3 February 1901           04:29:42 pm
# 14      Tuesday        5 March 1901           09:04:06 am
# ...
